# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
person_0 = []
directory = './data/0'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        person_1.append(np.load(f))

# %%
person_1 = []
directory = './data/1'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        person_1.append(np.load(f))

# %%
person_0 = np.array(person_0)
person_1 = np.array(person_1)

# %%
person_0.shape
# Out:
# (21, 500, 12)

# %%
person_1.shape
# Out:
# (14, 500, 12)

# %%
avg_reading = np.mean(person_0[0], axis=1)

# %%
avg_reading.shape
# Out:
# (500,)

# %%
plt.figure()
plt.plot(avg_reading)

# %%
plt.figure()
plt.plot(np.mean(person_0[0, :,0:3], axis=1))
